# %% [markdown]
# # S4E1 - Bank Churn Predictions - Ensemble N Models and FE

# %% [markdown]
# # Config

# %%
class Config():
    seed = 12
    folds = 5
    add_orig = True
    oofs = []
    preds = []
    models = []

config = Config()

# %% [markdown]
# # Imports

# %%
import random
import numpy as np 
import pandas as pd 
pd.set_option('display.max_columns', 50)

import matplotlib.pyplot as plt 
import plotly.express as px
import seaborn as sns
sns.set_style('whitegrid')

import warnings
warnings.filterwarnings("ignore")

from tqdm.auto import tqdm

# %% [markdown]
# # Load Files

# %%
root_dir = '/kaggle/input/playground-series-s4e1'
train = pd.read_csv(root_dir + '/train.csv') 
test = pd.read_csv(root_dir + '/test.csv') 
ss = pd.read_csv(root_dir + '/sample_submission.csv')

# %% [markdown]
# ## Load original data

# %%
orig = pd.read_csv('/kaggle/input/bank-customer-churn-prediction/Churn_Modelling.csv')
orig.drop('RowNumber',axis=1,inplace=True)
orig.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female  42.0       2
# 1    15647311      Hill          608     Spain  Female  41.0       1
# 2    15619304      Onio          502    France  Female  42.0       8
# 3    15701354      Boni          699    France  Female  39.0       1
# 4    15737888  Mitchell          850     Spain  Female  43.0       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1        1.0             1.0        101348.88
# 1   83807.86              1        0.0             1.0        112542.58
# 2  159660.80              3        1.0             0.0        113931.57
# 3       0.00              2        0.0             0.0         93826.63
# 4  125510.82              1        NaN             1.0         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
# a few values have nans in the orig data (like 3 rows), just drop them
orig.dropna(axis=0,inplace=True)
#orig.info()

# %%
train.drop('id',axis=1,inplace=True)
test.drop('id',axis=1,inplace=True)

# %% [markdown]
# ## Concatenate train + orig

# %%
if config.add_orig:
    train = pd.concat([train,orig],axis=0)

# %% [markdown]
# # Top Level EDA

# %%
# print all sets - assuming train,test, ss
print(f'Training Data Shape: {train.shape}') 
display(train.head()) 
print(f'Test Data Shape: {test.shape}') 
display(test.head()) 
print(f'Sample Submission Shape: {ss.shape}') 
display(ss.head())
# Out:
# Training Data Shape: (175032, 13)
#    CustomerId         Surname  CreditScore Geography Gender   Age  Tenure  \
# 0    15674932  Okwudilichukwu          668    France   Male  33.0       3
# 1    15749177   Okwudiliolisa          627    France   Male  33.0       1
# 2    15694510           Hsueh          678    France   Male  40.0      10
# 3    15741417             Kao          581    France   Male  34.0       2
# 4    15766172       Chiemenam          716     Spain   Male  33.0       5
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              2        1.0             0.0        181449.97
# 1       0.00              2        1.0             1.0         49503.50
# 2       0.00              2        1.0             0.0        184866.69
# 3  148882.54              1        1.0             1.0         84560.88
# 4       0.00              2        1.0             1.0         15068.83
#
#    Exited
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# Test Data Shape: (110023, 12)
#    CustomerId    Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0    15773898   Lucchese          586    France  Female  23.0       2
# 1    15782418       Nott          683    France  Female  46.0       2
# 2    15807120         K?          656    France  Female  34.0       7
# 3    15808905  O'Donnell          681    France    Male  36.0       8
# 4    15607314    Higgins          752   Germany    Male  38.0      10
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0       0.00              2        0.0             1.0        160976.75
# 1       0.00              1        1.0             0.0         72549.27
# 2       0.00              2        1.0             0.0        138882.09
# 3       0.00              1        1.0             0.0        113931.57
# 4  121263.62              1        1.0             0.0        139431.00
# Sample Submission Shape: (110023, 2)
#        id  Exited
# 0  165034     0.5
# 1  165035     0.5
# 2  165036     0.5
# 3  165037     0.5
# 4  165038     0.5

# %%
# display(train.describe().style.background_gradient(cmap='Blues'))
# display(test.describe().style.background_gradient(cmap='Blues'))

# %%
def num_of_unique_elements(df): 
  summary = pd.DataFrame(df.dtypes, columns=['dtypes']) 
  summary['missing#'] = df.isna().sum() 
  summary['missing%'] = (df.isna().sum())/len(df) 
  summary['uniques'] = df.nunique().values 
  summary['count'] = df.count().values 
  return summary

num_of_unique_elements(train).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_59c78_row0_col1, #T_59c78_row0_col2, #T_59c78_row0_col4, #T_59c78_row1_col1, #T_59c78_row1_col2, #T_59c78_row1_col4, #T_59c78_row2_col1, #T_59c78_row2_col2, #T_59c78_row2_col4, #T_59c78_row3_col1, #T_59c78_row3_col2, #T_59c78_row3_col3, #T_59c78_row3_col4, #T_59c78_row4_col1, #T_59c78_row4_col2, #T_59c78_row4_col3, #T_59c78_row4_col4, #T_59c78_row5_col1, #T_59c78_row5_col2, #T_59c78_row5_col3, #T_59c78_row5_col4, #T_59c78_row6_col1, #T_59c78_row6_col2, #T_59c78_row6_col3, #T_59c78_row6_col4, #T_59c78_row7_col1, #T_59c78_row7_col2, #T_59c78_row7_col4, #T_59c78_row8_col1, #T_59c78_row8_col2, #T_59c78_row8_col3, #T_59c78_row8_col4, #T_59c78_row9_col1, #T_59c78_row9_col2, #T_59c78_row9_col3, #T_59c78_row9_col4, #T_59c78_row10_col1, #T_59c78_row10_col2, #T_59c78_row10_col3, #T_59c78_row10_col4, #T_59c78_row11_col1, #T_59c78_row11_col2, #T_59c78_row11_col4, #T_59c78_row12_col1, #T_59c78_row12_col2, #T_59c78_row12_col3, #T_59c78_row12_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_59c78_row0_col3 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_59c78_row1_col3 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_59c78_row2_col3 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_59c78_row7_col3 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_59c78_row11_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_59c78">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_59c78_level0_col0" class="col_heading level0 col0" >dtypes</th>
#       <th id="T_59c78_level0_col1" class="col_heading level0 col1" >missing#</th>
#       <th id="T_59c78_level0_col2" class="col_heading level0 col2" >missing%</th>
#       <th id="T_59c78_level0_col3" class="col_heading level0 col3" >uniques</th>
#       <th id="T_59c78_level0_col4" class="col_heading level0 col4" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_59c78_level0_row0" class="row_heading level0 row0" >CustomerId</th>
#       <td id="T_59c78_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_59c78_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_59c78_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_59c78_row0_col3" class="data row0 col3" >23421</td>
#       <td id="T_59c78_row0_col4" class="data row0 col4" >175032</td>
#     </tr>
#     <tr>
#       <th id="T_59c78_level0_row1" class="row_heading level0 row1" >Surname</th>
#       <td id="T_59c78_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_59c78_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_59c78_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_59c78_row1_col3" class="data row1 col3" >2932</td>
#       <td id="T_59c78_row1_col4" class="data row1 col4" >175032</td>
#     </tr>
#     <tr>
#       <th id="T_59c78_level0_row2" class="row_heading level0 row2" >CreditScore</th>
#       <td id="T_59c78_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_59c78_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_59c78_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_59c78_row2_col3" class="data row2 col3" >460</td>
#       <td id="T_59c78_row2_col4" class="data row2 col4" >175032</td>
#     </tr>
#     <tr>
#       <th id="T_59c78_level0_row3" class="row_heading level0 row3" >Geography</th>
#       <td id="T_59c78_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_59c78_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_59c78_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_59c78_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_59c78_row3_col4" class="data row3 col4" >175032</td>
#     </tr>
#     <tr>
#       <th id="T_59c78_level0_row4" class="row_heading level0 row4" >Gender</th>
#       <td id="T_59c78_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_59c78_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_59c78_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_59c78_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_59c78_row4_col4" class="data row4 col4" >175032</td>
#     </tr>
#     <tr>
#       <th id="T_59c78_level0_row5" class="row_heading level0 row5" >Age</th>
#       <td id="T_59c78_row5_col0" class="data row5 col0" >float64</td>
#       <td id="T_59c78_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_59c78_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_59c78_row5_col3" class="data row5 col3" >73</td>
#       <td id="T_59c78_row5_col4" class="data row5 col4" >175032</td>
#     </tr>
#     <tr>
#       <th id="T_59c78_level0_row6" class="row_heading level0 row6" >Tenure</th>
#       <td id="T_59c78_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_59c78_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_59c78_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_59c78_row6_col3" class="data row6 col3" >11</td>
#       <td id="T_59c78_row6_col4" class="data row6 col4" >175032</td>
#     </tr>
#     <tr>
#       <th id="T_59c78_level0_row7" class="row_heading level0 row7" >Balance</th>
#       <td id="T_59c78_row7_col0" class="data row7 col0" >float64</td>
#       <td id="T_59c78_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_59c78_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_59c78_row7_col3" class="data row7 col3" >30239</td>
#       <td id="T_59c78_row7_col4" class="data row7 col4" >175032</td>
#     </tr>
#     <tr>
#       <th id="T_59c78_level0_row8" class="row_heading level0 row8" >NumOfProducts</th>
#       <td id="T_59c78_row8_col0" class="data row8 col0" >int64</td>
#       <td id="T_59c78_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_59c78_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_59c78_row8_col3" class="data row8 col3" >4</td>
#       <td id="T_59c78_row8_col4" class="data row8 col4" >175032</td>
#     </tr>
#     <tr>
#       <th id="T_59c78_level0_row9" class="row_heading level0 row9" >HasCrCard</th>
#       <td id="T_59c78_row9_col0" class="data row9 col0" >float64</td>
#       <td id="T_59c78_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_59c78_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_59c78_row9_col3" class="data row9 col3" >2</td>
#       <td id="T_59c78_row9_col4" class="data row9 col4" >175032</td>
#     </tr>
#     <tr>
#       <th id="T_59c78_level0_row10" class="row_heading level0 row10" >IsActiveMember</th>
#       <td id="T_59c78_row10_col0" class="data row10 col0" >float64</td>
#       <td id="T_59c78_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_59c78_row10_col2" class="data row10 col2" >0.000000</td>
#       <td id="T_59c78_row10_col3" class="data row10 col3" >2</td>
#       <td id="T_59c78_row10_col4" class="data row10 col4" >175032</td>
#     </tr>
#     <tr>
#       <th id="T_59c78_level0_row11" class="row_heading level0 row11" >EstimatedSalary</th>
#       <td id="T_59c78_row11_col0" class="data row11 col0" >float64</td>
#       <td id="T_59c78_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_59c78_row11_col2" class="data row11 col2" >0.000000</td>
#       <td id="T_59c78_row11_col3" class="data row11 col3" >55581</td>
#       <td id="T_59c78_row11_col4" class="data row11 col4" >175032</td>
#     </tr>
#     <tr>
#       <th id="T_59c78_level0_row12" class="row_heading level0 row12" >Exited</th>
#       <td id="T_59c78_row12_col0" class="data row12 col0" >int64</td>
#       <td id="T_59c78_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_59c78_row12_col2" class="data row12 col2" >0.000000</td>
#       <td id="T_59c78_row12_col3" class="data row12 col3" >2</td>
#       <td id="T_59c78_row12_col4" class="data row12 col4" >175032</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# * 165K rows in train, 110K rows in test, 13 features + target
# * No missing data
# * Some categorical/binary columns
# * Some columns have non-optimum data types
# * Age should be int

# %% [markdown]
# # Feature Engineering

# %%
# FE thanks to https://www.kaggle.com/competitions/playground-series-s4e1/discussion/469782

def get_feats(df): 
    
    df["Surname_First_Letter"] = df["Surname"].apply(lambda x: x[0]) 
    df["Age_NumOfProducts"] = df["Age"] ** df["NumOfProducts"] 
    df['IsSenior'] = df['Age'].apply(lambda x: 1 if x >= 60 else 0) 
    df['IsActive_by_CreditCard'] = df['HasCrCard'] * df['IsActiveMember'] 
    df['Products_Per_Tenure'] = df['Tenure'] / df['NumOfProducts'] 
    df['AgeCat'] = np.round(df.Age/20).astype('int').astype('category') 
    df['AvgBalancePerProduct'] = df['Balance'] / df['NumOfProducts'] 
    df['TenureToAgeRatio'] = df['Tenure'] / df['Age'] 
    df['Balance_to_Salary_Ratio'] = df['Balance'] / df['EstimatedSalary'] 
    df['CreditScoreTier'] = pd.cut(df['CreditScore'], bins=[0, 650, 750, 850], labels=['Low', 'Medium', 'High']) 
    
    return df

train = get_feats(train)
test = get_feats(test)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 175032 entries, 0 to 10001
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   CustomerId               175032 non-null  int64
#  1   Surname                  175032 non-null  object
#  2   CreditScore              175032 non-null  int64
#  3   Geography                175032 non-null  object
#  4   Gender                   175032 non-null  object
#  5   Age                      175032 non-null  float64
#  6   Tenure                   175032 non-null  int64
#  7   Balance                  175032 non-null  float64
#  8   NumOfProducts            175032 non-null  int64
#  9   HasCrCard                175032 non-null  float64
#  10  IsActiveMember           175032 non-null  float64
#  11  EstimatedSalary          175032 non-null  float64
#  12  Exited                   175032 non-null  int64
#  13  Surname_First_Letter     175032 non-null  object
#  14  Age_NumOfProducts        175032 non-null  float64
#  15  IsSenior                 175032 non-null  int64
#  16  IsActive_by_CreditCard   175032 non-null  float64
#  17  Products_Per_Tenure      175032 non-null  float64
#  18  AgeCat                   175032 non-null  category
#  19  AvgBalancePerProduct     175032 non-null  float64
#  20  TenureToAgeRatio         175032 non-null  float64
#  21  Balance_to_Salary_Ratio  175032 non-null  float64
#  22  CreditScoreTier          175032 non-null  category
# dtypes: category(2), float64(11), int64(6), object(4)
# memory usage: 29.7+ MB

# %% [markdown]
# ## Convert Datatypes
# * to something more reasonable
# * Gender, HasCrCard, IsActiveMember, Exited to boolean

# %%
# convert colums to boolean 
bool_cols = [col for col in train.columns if train[col].nunique()==2]
train[bool_cols] = train[bool_cols].astype('bool')

y = train.Exited
bool_cols.remove('Exited')
test[bool_cols] = test[bool_cols].astype('bool')

cat_cols = [col for col in test.columns if test[col].dtype=='object']
train[cat_cols] = train[cat_cols].astype('category')
test[cat_cols] = test[cat_cols].astype('category')
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110023 entries, 0 to 110022
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   CustomerId               110023 non-null  int64
#  1   Surname                  110023 non-null  category
#  2   CreditScore              110023 non-null  int64
#  3   Geography                110023 non-null  category
#  4   Gender                   110023 non-null  bool
#  5   Age                      110023 non-null  float64
#  6   Tenure                   110023 non-null  int64
#  7   Balance                  110023 non-null  float64
#  8   NumOfProducts            110023 non-null  int64
#  9   HasCrCard                110023 non-null  bool
#  10  IsActiveMember           110023 non-null  bool
#  11  EstimatedSalary          110023 non-null  float64
#  12  Surname_First_Letter     110023 non-null  category
#  13  Age_NumOfProducts        110023 non-null  float64
#  14  IsSenior                 110023 non-null  bool
#  15  IsActive_by_CreditCard   110023 non-null  bool
#  16  Products_Per_Tenure      110023 non-null  float64
#  17  AgeCat                   110023 non-null  category
#  18  AvgBalancePerProduct     110023 non-null  float64
#  19  TenureToAgeRatio         110023 non-null  float64
#  20  Balance_to_Salary_Ratio  110023 non-null  float64
#  21  CreditScoreTier          110023 non-null  category
# dtypes: bool(5), category(5), float64(8), int64(4)
# memory usage: 11.3 MB

# %%
cat_cols = [col for col in test.columns if test[col].dtype=='category']
cat_cols
# Out:
# ['Surname', 'Geography', 'Surname_First_Letter', 'AgeCat', 'CreditScoreTier']

# %%
# one hot encode non-ordinal columns (geography)
# train = pd.concat([train, pd.get_dummies(train['Geography'])], axis=1)
# test = pd.concat([test, pd.get_dummies(test['Geography'])], axis=1)
# train

# %%
# train.drop('Geography', axis=1, inplace=True)
# test.drop('Geography', axis=1, inplace=True)

# %%
train['surlength'] = train['Surname'].apply(len)
test['surlength'] = test['Surname'].apply(len)

# not_used_cols = ['CustomerId','Surname']

# train.drop(not_used_cols, axis=1, inplace=True)
# test.drop(not_used_cols, axis=1, inplace=True)

# %%
y.value_counts().plot(kind='bar')
plt.title('Target Value Counts')
# Out:
# Text(0.5, 1.0, 'Target Value Counts')

# %% [markdown]
# * Some target class imbalance
#     * Try oversampling

# %% [markdown]
# ## Select Features

# %%
test.drop('CustomerId',axis=1,inplace=True)
train.drop('CustomerId',axis=1,inplace=True)
features = [col for col in test.columns]
features
# Out:
# ['Surname',
#  'CreditScore',
#  'Geography',
#  'Gender',
#  'Age',
#  'Tenure',
#  'Balance',
#  'NumOfProducts',
#  'HasCrCard',
#  'IsActiveMember',
#  'EstimatedSalary',
#  'Surname_First_Letter',
#  'Age_NumOfProducts',
#  'IsSenior',
#  'IsActive_by_CreditCard',
#  'Products_Per_Tenure',
#  'AgeCat',
#  'AvgBalancePerProduct',
#  'TenureToAgeRatio',
#  'Balance_to_Salary_Ratio',
#  'CreditScoreTier',
#  'surlength']

# %% [markdown]
# # Models

# %%
from sklearn.metrics import roc_auc_score, confusion_matrix
from sklearn.model_selection import train_test_split, StratifiedKFold

# %% [markdown]
# ## Train/test Split

# %%
X_train, X_valid, y_train, y_valid = train_test_split(train[features], y, train_size=0.8, test_size=0.2,
                                                      random_state=config.seed)
X_test = test[features]

# %% [markdown]
# ### Cross Validation

# %%
def run_cv_and_predict(train, test, features, model, seed, verbose=True):
    
    # initialize arrays 
    fold_scores = []
    oof = np.zeros(train.shape[0])
    preds = np.zeros((test.shape[0],config.folds))

    # setup folding strategy
    skf = StratifiedKFold(n_splits=config.folds,random_state = config.seed,shuffle=True)

    # start cross validation
    cur_fold = 1
    for trn_idx, val_idx in skf.split(train[features], y):

        # split indicies into train and validation
        x_train = train[features].iloc[trn_idx]
        y_train = y.iloc[trn_idx]
        x_valid = train[features].iloc[val_idx]
        y_valid = y.iloc[val_idx]

        # fit model
        model.fit(x_train,y_train)

        # predict on validation set
        fold_preds = model.predict_proba(x_valid)[:,1]
        fold_preds = fold_preds.reshape(len(fold_preds)) # sbabwtdt
        oof[val_idx] = fold_preds

        # Compute scores
        fold_score = roc_auc_score(y_valid,fold_preds)  # CHOOSE METRIC HERE
        fold_scores.append(fold_score)
        if verbose:
          print(f'Score, fold {cur_fold}: {fold_score}')

        # predict on test set - store all fold preds (take mode later)
        test_preds = model.predict_proba(test[features])[:,1]
        test_preds = test_preds.reshape(len(test_preds))  # shouldn't have to do this.
        preds[:,cur_fold-1] = test_preds  
        cur_fold +=1
    
    # Print mean fold and oof score 
    oof_score = roc_auc_score(y,oof)
    # oof_score = np.sqrt(mean_squared_error(y,oof))
    print(f'ROC AUC score: {np.mean(fold_scores):.5f}, Stdev: {np.std(fold_scores):.5f}, OOF score: {oof_score:.5f}')
    # print(f'RMSE score: {np.mean(scores):.5f}, Stdev: {np.std(scores):.5f}, OOF score: {oof_score:.5f}')

    return (preds,fold_scores,oof_score,oof)

# %% [markdown]
# ## Logistic Regression

# %%
# from sklearn.linear_model import LogisticRegression

# model_lr = LogisticRegression()

# preds_lr,scores_lr,oof_score_lr,oof_lr = run_cv_and_predict(train,test,features,model_lr,config.seed,verbose=True)

# config.oofs.append(oof_lr)
# config.preds.append(preds_lr)
# config.models.append('lr')
# default: 0.71144,                  lb = .70793
# with cross validation: .71380,     lb = .70791

# %% [markdown]
# ## Decision Tree

# %%
# from sklearn.tree import DecisionTreeClassifier

# results = []
# for msl in [10,]:
#     for mss in [11]:
#         for d in [8]:
#             model_dt = DecisionTreeClassifier(min_samples_leaf=msl, min_samples_split=mss,max_depth=d)
#             print(f'msl: {msl},mss: {mss},d:{d}')
#             preds_dt,scores_dt,oof_score_dt,oof_dt = run_cv_and_predict(train,test,features,model_dt,config.seed,verbose=False)

            
# config.oofs.append(oof_dt)
# config.preds.append(preds_dt)
# config.models.append('dt')
# default .69954
# max_depth = 3: .84321
# max_depth = 4: .86051
# max_depth = 5: .87173
# max_depth = 6: .88061, lb = .87575
# max_depth = 7: .88137, lb = .87771
# max_depth = 8: .88028, lb = .87785
# max_depth = 9: .87648

# %% [markdown]
# ## Random Forest

# %%
# from sklearn.ensemble import RandomForestClassifier
# model_rf = RandomForestClassifier()

# preds_rf,scores_rf,oof_score_rf,oof_rf = run_cv_and_predict(train,test,features,model_rf,config.seed,verbose=True)

# config.oofs.append(oof_rf)
# config.preds.append(preds_rf)
# config.models.append('rf')
# default: cv = .86870, lb = .87105
# default with orig: .86404

# %% [markdown]
# ## Extra Trees

# %%
# %%time
# from sklearn.ensemble import ExtraTreesClassifier

# results = []

# for est in [500]:
#     for md in [7]:
#         for msl in [4]:
#             model_etc = ExtraTreesClassifier(n_estimators=est,max_depth=md,min_samples_leaf=msl, random_state=config.seed)
#             print(f'est: {est},md: {md}, msl: {msl}')
#             preds_etc,scores_etc,oof_score_etc,oof_etc = run_cv_and_predict(train,test,features,model_etc,config.seed,verbose=False)
#             results.append([est,md,msl,np.mean(scores_etc),oof_score_etc])
# config.oofs.append(oof_etc)
# config.preds.append(preds_etc)
# config.models.append('etc')

#default etc = .86235, lb = .86639
# nest, max_depth, msl = 500,7,4, cv = .87727
# orig data: est: 500,md: 7, msl: 4,  ROC AUC score: 0.86332, Stdev: 0.00249, OOF score: 0.86326

# %%
# model_etc.get_params()

# %% [markdown]
# # XGBoost

# %%
# %%time
# from xgboost import XGBClassifier

# results = []



# results = []

# for est in [600]:
#     for md in [5]:
#         for lr in [.03]:
#             model_xgb = XGBClassifier(max_depth=md, 
#                                       n_estimators=est, 
#                                       learning_rate=lr,
#                                       random_state= config.seed  
#                                       )
#             print(f'est: {est}, md: {md}, lr: {lr}')
#             preds_xgb,scores_xgb,oof_score_xgb,oof_xgb = run_cv_and_predict(train,test,features,model_xgb,config.seed,verbose=False)
#             results.append([est,md,lr,np.mean(scores_xgb),oof_score_xgb])

# config.oofs.append(oof_xgb)
# config.preds.append(preds_xgb)
# config.models.append('xgb')

# default xgb = .88284, lb = .88212 (very close match)
# params1 (est,md,lr): 125,8,.03, cv = .88442, lb = .88022 
# 125,7,.05: .88507, lb = .88146
# 250,5,.04: .88544, lb = ,88190
# 500,5,.04: .88557, lb = .88265
# 1000,4,.03: .88570, lb = .88232
# 1000,4, .025: ROC AUC score: 0.88575, Stdev: 0.00232, OOF score: 0.88573, lb = .88221
# change to .02, .88569
# 2000, 3, .02: .88530
# 2000, 4, .02: .88569
# 1000, 5, .02: .88562
# 1000, 5, .01: .88545, ROC AUC score: 0.88545, Stdev: 0.00224, OOF score: 0.88542, lb = .88184
# 1000, 5, .03: .88538
# 1000, 5, .05: .88464, 
# 1000, 6 ,.05: .88307
# 1000, 4, .05: ROC AUC score: 0.88546, Stdev: 0.00254, OOF score: 0.88545
# 1000, 3, .05: ROC AUC score: 0.88574, Stdev: 0.00238, OOF score: 0.88573, lb = .88218
# 1000, 3, .04: ROC AUC score: 0.88566, Stdev: 0.00240, OOF score: 0.88564
# 1000, 3, .06: ROC AUC score: 0.88582, Stdev: 0.00240, OOF score: 0.88580, lb = .88224
# 1000, 3, .07, ROC AUC score: 0.88577, Stdev: 0.00234, OOF score: 0.88576
# 1500, 3, .07, ROC AUC score: 0.88553, Stdev: 0.00237, OOF score: 0.88552

# 500, 5, .04: ROC AUC score: 0.88557, Stdev: 0.00236, OOF score: 0.88555
# add orig: ROC AUC score: 0.88465, Stdev: 0.00178, OOF score: 0.88461

#5, .02 seems to be good...
# 600, 5, .03: .88459
# add len(surname): 600,5,.03 = .88581

# %%
# train on full set with best feats so far (500,5,.04) with random seeds, not even the best...
# n = 10
# preds = np.zeros((len(X_test),n))
# for seed in tqdm(range(10)):
#     model_xgb = XGBClassifier(max_depth= 5, 
#                           n_estimators= 500, 
#                           learning_rate=0.04,
#                           random_state= seed  
#                           )
    
#     model_xgb.fit(train[features],y)
#     preds[:,seed] = model_xgb.predict_proba(X_test)[:,1]
    
# preds

# %%
cat_cols
# Out:
# ['Surname', 'Geography', 'Surname_First_Letter', 'AgeCat', 'CreditScoreTier']

# %% [markdown]
# ## Catboost

# %%
from catboost import CatBoostClassifier

model_cat = CatBoostClassifier(verbose=False,
                          cat_features = cat_cols,
#                           max_depth= 5, 
#                           n_estimators= 500, 
#                           learning_rate=0.04,
                          random_state= config.seed  
                          )

preds_cat,scores_cat,oof_score_cat,oof_cat = run_cv_and_predict(train,test,features,model_cat,config.seed,verbose=True)

config.oofs.append(oof_cat)
config.preds.append(preds_cat)
config.models.append('cat')

# default cv = .88475, lb = .88192
# add orig data: ROC AUC score: 0.88387, Stdev: 0.00185, OOF score: 0.88384 (lower)
# add len(surname): default: .88397

# adding features (see above), .89018 (much higher cv!), lb = .88712 (prev best was .88288!)
# Out:
# Score, fold 1: 0.8917161400220879
# Score, fold 2: 0.8910566438811958
# Score, fold 3: 0.8879506599785554
# Score, fold 4: 0.8913487069110122
# Score, fold 5: 0.8888429981874431
# ROC AUC score: 0.89018, Stdev: 0.00150, OOF score: 0.89015

# %%
len(preds_cat.mean(axis=1))
# Out:
# 110023

# %% [markdown]
# ## LightGBM

# %%
# from lightgbm import LGBMClassifier

# model_lgbm = LGBMClassifier(n_estimators=100,random_state=config.seed)

# preds_lgbm,scores_lgbm,oof_score_lgbm,oof_lgbm = run_cv_and_predict(train,test,features,model_lgbm,config.seed,verbose=True)


# config.oofs.append(oof_lgbm)
# config.preds.append(preds_lgbm)
# config.models.append('lgbm')


# default ROC AUC score: 0.88547, Stdev: 0.00235, OOF score: 0.88544, lb = .88205
# 200 est: ROC AUC score: 0.88519, Stdev: 0.00240, OOF score: 0.88517, default lr: .1
# 100 est, lr:.05, ROC AUC score: 0.88516, Stdev: 0.00228, OOF score: 0.88511
# 100 est, lr: .025: .88369
# 300 est, lr: .025: .ROC AUC score: 0.88552, Stdev: 0.00237, OOF score: 0.88548
# 400 est, lr: .025: ROC AUC score: 0.88562, Stdev: 0.00238, OOF score: 0.88559
# 500 est, lr: .05, num leaves=25, ROCAUC = .88543, stdev=.00237, oof = .88541
# same but with orig: ROC AUC score: 0.88443, Stdev: 0.00167, OOF score: 0.88438
# add len(surname), cv = .88464

# default with FE: .88347 (must not be using cat cols), not changin with estimators so something is up...

# Create LightGBM datasets for training and validation using X_train, y_train, X_valid, and y_valid.
train_data = lgb.Dataset(X_train, label=y_train, categorical_feature=['Pclass'])
valid_data = lgb.Dataset(X_valid, label=y_valid, reference=train_data)

# %%
# model_lgbm.get_params()

# %% [markdown]
# # N-Model Stochastic Ensemble
# * Using oof predictions, optimize model ratio and generate predictions

# %%
#config.oofs
# Out:
# [array([0.01967574, 0.00712311, 0.04615382, ..., 0.17921154, 0.06009243,
#         0.06009243])]

# %%
# %%time

# # list of oof and predictions for each model
# # oofs = [oof_dt,oof_rf,oof_lgbm]
# # preds = [preds_dt,preds_rf,preds_lgbm]  # maybe I should just return the mean value of preds in the cv function (?)
# oofs = config.oofs
# preds = config.preds
# models = config.models

# y = y.astype(int)

# num_trials = 3000
# m = []

# # loop through random trials and compute the scores
# for i in range(num_trials):
#     # generate a list of random numbers
#     rands = np.array([random.random() for i in range(len(oofs))])
#     tot = sum(rands)
#     rands = rands/tot
#     tm_ens = sum([rands[j] * oofs[j] for j in range(len(oofs))])    
#     tm_score = roc_auc_score(y,tm_ens)  # swap out error function here
#     row = [r for r in rands]
#     row.append(tm_score)
#     m.append(row)
   
# # save arrays into a dataframe
# #cols = ['r'+str(i) for i in range(len(rands))]
# cols = [config.models[i] for i in range(len(rands))]

# cols.append('score')
# ens_model = pd.DataFrame(m,columns=cols)

# # get max row by sorting and taking the top row
# ens_model = ens_model.sort_values('score', ascending=False)
# max_row = ens_model.iloc[0]
# feats = [row for row in ens_model.columns if row != 'score']

# # get ratios of maximum row
# ratios = max_row[feats]

# #multiply ratio * predictions
# preds_ens = sum([ratios[i] * preds[i].mean(axis=1) for i in range(len(preds))])

# w/o orig data, ens modles are around .88590
# with orig data:

# %%
# ens_model.head()

# %% [markdown]
# ## Select final preds and plot distribution

# %%
final_preds = preds_cat.mean(axis=1)#preds_ens

plt.hist(final_preds,bins=20)
plt.title('Distribution of Predictions');

# %%
ss.Exited = final_preds
ss.to_csv('submission.csv',index=False)
ss.head()
# Out:
#        id    Exited
# 0  165034  0.013257
# 1  165035  0.753440
# 2  165036  0.012991
# 3  165037  0.279187
# 4  165038  0.432104

# %% [markdown]
# ## Print Ratios and Models

# %%
# output = [config.models[i] + ':' + f'{max_row[i]:.2f}' for i in range(len(models))]
# output = ' '.join(output) + f', cv: {max_row.score:.5f}'
# output

# %%
# 100 trials: .88550
